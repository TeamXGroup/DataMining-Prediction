# %% [markdown]
# # Prédiction du Secteur le plus rentable au Maroc

# %% [markdown]
# **Nettoyage et Prétraitement des Données**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# %%
df= pd.read_csv(r"C:\Users\DELL\Documents\projet_data_mining\DataSet.csv")
df.head()
# Out:
#        Secteur  Année Actifs occupés Capitalisation boursière  \
# 0  Agriculture   2010            NaN                    25269
# 1  Agriculture   2011           39,8                    20253
# 2  Agriculture   2012           39,2                    24546
# 3  Agriculture   2013           39,3                    26768
# 4  Agriculture   2014           39,4                    25781
#
#   Consommation Finale  Consommation intermédiaire  \
# 0                 NaN                     50579.0
# 1         68921.31431                     57002.0
# 2                 NaN                     59077.0
# 3         69531.01265                     61613.0
# 4         71980.46408                     61861.0
#
#    Excédent brut d'exploitation Exportations Importations         FBCF  \
# 0                       89427.0          NaN          NaN          NaN
# 1                       95308.0  13318.75732  16005.18334  5495,191774
# ...

# %%
df.shape
# Out:
# (77, 15)

# %%
df.isnull().sum()
# Out:
# Secteur                          0
# Année                            0
# Actifs occupés                  37
# Capitalisation boursière        14
# Consommation Finale              8
# Consommation intermédiaire       7
# Excédent brut d'exploitation    14
# Exportations                    17
# Importations                    17
# FBCF                            37
# Impôts sur les produits          7
# PIB                              7
# Production nationale             7
# Salaires bruts                  14
# Volume des échanges             21
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 207

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Secteur                       77 non-null     object
#  1   Année                         77 non-null     int64
#  2   Actifs occupés                40 non-null     object
#  3   Capitalisation boursière      63 non-null     object
#  4   Consommation Finale           69 non-null     object
#  5   Consommation intermédiaire    70 non-null     float64
#  6   Excédent brut d'exploitation  63 non-null     float64
#  7   Exportations                  60 non-null     object
#  8   Importations                  60 non-null     object
#  9   FBCF                          40 non-null     object
#  10  Impôts sur les produits       70 non-null     float64
#  11  PIB                           70 non-null     object
# ...

# %%
df=df.dropna(thresh=41,axis=1)

# %%
for i in range(2010,2021):
    null_valeur_par_annee=df[df['Année'] == i].isnull().sum(axis=1).sum()
    print("l'annee",i,"=",null_valeur_par_annee)
    for j in ['Agriculture', 'Industrie', 'BTP', 'Énergie', 'Tourisme', 'Commerce', 'Services']:
        null_valeur_par_secteur=df[(df['Année'] == i) & (df['Secteur'] == j)].isnull().sum(axis=1).sum()
        print("\t",j,"=",null_valeur_par_secteur, "/13")
# Out:
# l'annee 2010 = 28
# 	 Agriculture = 4 /13
# 	 Industrie = 4 /13
# 	 BTP = 4 /13
# 	 Énergie = 4 /13
# 	 Tourisme = 4 /13
# 	 Commerce = 4 /13
# 	 Services = 4 /13
# l'annee 2011 = 2
# 	 Agriculture = 0 /13
# 	 Industrie = 0 /13
# 	 BTP = 0 /13
# 	 Énergie = 0 /13
# 	 Tourisme = 0 /13
# 	 Commerce = 2 /13
# 	 Services = 0 /13
# l'annee 2012 = 3
# 	 Agriculture = 1 /13
# 	 Industrie = 0 /13
# 	 BTP = 0 /13
# 	 Énergie = 0 /13
# 	 Tourisme = 0 /13
# 	 Commerce = 2 /13
# 	 Services = 0 /13
# l'annee 2013 = 2
# 	 Agriculture = 0 /13
# 	 Industrie = 0 /13
# 	 BTP = 0 /13
# 	 Énergie = 0 /13
# 	 Tourisme = 0 /13
# 	 Commerce = 2 /13
# 	 Services = 0 /13
# l'annee 2014 = 2
# 	 Agriculture = 0 /13
# 	 Industrie = 0 /13
# 	 BTP = 0 /13
# 	 Énergie = 0 /13
# 	 Tourisme = 0 /13
# 	 Commerce = 2 /13
# 	 Services = 0 /13
# l'annee 2015 = 2
# 	 Agriculture = 0 /13
# 	 Industrie = 0 /13
# 	 BTP = 0 /13
# 	 Énergie = 0 /13
# 	 Tourisme = 0 /13
# 	 Commerce = 2 /13
# 	 Services = 0 /13
# ...

# %%
df=df.dropna(thresh=10,axis=0)

# %%
for i in range(2010,2021):
    null_valeur_par_annee=df[df['Année'] == i].isnull().sum(axis=1).sum()
    print("l'annee",i,"=",null_valeur_par_annee)
# Out:
# l'annee 2010 = 0.0
# l'annee 2011 = 2
# l'annee 2012 = 3
# l'annee 2013 = 2
# l'annee 2014 = 2
# l'annee 2015 = 2
# l'annee 2016 = 2
# l'annee 2017 = 2
# l'annee 2018 = 9
# l'annee 2019 = 0.0
# l'annee 2020 = 0.0

# %%
df.isnull().sum()
# Out:
# Secteur                         0
# Année                           0
# Capitalisation boursière        0
# Consommation Finale             1
# Consommation intermédiaire      0
# Excédent brut d'exploitation    0
# Exportations                    8
# Importations                    8
# Impôts sur les produits         0
# PIB                             0
# Production nationale            0
# Salaires bruts                  0
# Volume des échanges             7
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 24

# %%
x=df[['Importations','Exportations']].fillna(0)
df.update(x)

# %%
df=df.ffill()

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, 1 to 74
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Secteur                       56 non-null     object
#  1   Année                         56 non-null     int64
#  2   Capitalisation boursière      56 non-null     object
#  3   Consommation Finale           56 non-null     object
#  4   Consommation intermédiaire    56 non-null     float64
#  5   Excédent brut d'exploitation  56 non-null     float64
#  6   Exportations                  56 non-null     object
#  7   Importations                  56 non-null     object
#  8   Impôts sur les produits       56 non-null     float64
#  9   PIB                           56 non-null     object
#  10  Production nationale          56 non-null     float64
#  11  Salaires bruts                56 non-null     float64
# ...

# %%
column_name = 'Capitalisation boursière','Consommation Finale','Exportations','Importations','PIB','Volume des échanges' 

for name in column_name:
     df[name] = df[name].apply(lambda x: float(x.replace(',', '.')) if isinstance(x, str) else x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, 1 to 74
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Secteur                       56 non-null     object
#  1   Année                         56 non-null     int64
#  2   Capitalisation boursière      56 non-null     float64
#  3   Consommation Finale           56 non-null     float64
#  4   Consommation intermédiaire    56 non-null     float64
#  5   Excédent brut d'exploitation  56 non-null     float64
#  6   Exportations                  56 non-null     float64
#  7   Importations                  56 non-null     float64
#  8   Impôts sur les produits       56 non-null     float64
#  9   PIB                           56 non-null     float64
#  10  Production nationale          56 non-null     float64
#  11  Salaires bruts                56 non-null     float64
# ...

# %%
df.shape
# Out:
# (56, 13)

# %%
df.head(56)
# Out:
#         Secteur  Année  Capitalisation boursière  Consommation Finale  \
# 1   Agriculture   2011                  20253.00          68921.31431
# 2   Agriculture   2012                  24546.00          68921.31431
# 3   Agriculture   2013                  26768.00          69531.01265
# 4   Agriculture   2014                  25781.00          71980.46408
# 5   Agriculture   2015                  23982.00          74250.00000
# 6   Agriculture   2016                  26863.00          72807.00000
# 7   Agriculture   2017                  33294.00          77073.00000
# 8   Agriculture   2018                  32739.00          78466.00000
# 12    Industrie   2011                  43216.00         220169.70000
# 13    Industrie   2012                  39618.00         225478.33000
# 14    Industrie   2013                  35946.00         229210.41000
# 15    Industrie   2014                  33156.00         237109.07000
# ...
